# %%
import pandas
pandas.read_csv("covid_data.csv")
# Out:
#      Unnamed: 0         Country  Confirmed  Deaths  Mortality Ratio  \
# 0             0     Afghanistan    39145.0  1446.0             3.69
# 1             1         Albania    12787.0   370.0             2.89
# 2             2         Algeria    50400.0  1698.0             3.37
# 3             3         Andorra     1753.0    53.0             3.02
# 4             4          Angola     4363.0   159.0             3.64
# ..          ...             ...        ...     ...              ...
# 171         171         Vietnam     1069.0    35.0             3.27
# 172         172  Western Sahara       10.0     1.0            10.00
# 173         173           Yemen     2029.0   586.0            28.88
# 174         174          Zambia    14443.0   332.0             2.30
# 175         175        Zimbabwe     7725.0   227.0             2.94
#
#       Latitude   Longitude Country_Code
# 0    33.939110   67.709953           AF
# 1    41.153332   20.168331           AL
# ...
