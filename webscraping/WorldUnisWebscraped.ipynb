# %%
# Out:
# [<table class="table table-hover text-left">
# <thead>
# <tr>
# <th scope="col">University</th>
# <th class="text-nowrap" scope="col" style="width:65px">Country</th>
# </tr>
# </thead>
# <tbody>
# <tr>
# <td><a href="/reviews/9107.htm"> A.T. Still University</a></td>
# <td class="text-right">us <img alt="United States" class="fl flag-us" src="/i/bg.gif"/></td>
# </tr>
# <tr>
# <td><a href="/reviews/1160.htm"> Aalborg Universitet</a></td>
# <td class="text-right">dk <img alt="Denmark" class="fl flag-dk" src="/i/bg.gif"/></td>
# </tr>
# <tr>
# <td><a href="/reviews/1305.htm"> Aalto-yliopisto</a></td>
# <td class="text-right">fi <img alt="Finland" class="fl flag-fi" src="/i/bg.gif"/></td>
# </tr>
# <tr>
# <td><a href="/reviews/1164.htm"> Aarhus Universitet</a></td>
# <td class="text-right">dk <img alt="Denmark" class="fl flag-dk" src="/i/bg.gif"/></td>
# </tr>
# <tr>
# <td><a href="/reviews/18082.htm"> Aba Teachers University</a></td>
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-aba8f6543da3> in <module>
# ----> 1 r = requests.get("https://www.4icu.org/reviews/index2.htm")
#       2 type(r)
#       3 #c = r.content
#       4 #soup = BeautifulSoup(c, "html.parser")
#       5 #soup
#
# NameError: name 'requests' is not defined
